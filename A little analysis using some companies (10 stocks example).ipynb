# ..          ...         ...         ...         ...         ...         ...
# 248  2022-02-22  388.950012  392.420013  373.019989  377.380005  377.380005
# 249  2022-02-23  382.720001  386.000000  366.660004  367.459991  367.459991
# 250  2022-02-24  355.089996  390.730011  354.720001  390.029999  390.029999
# 251  2022-02-25  386.609985  391.290009  375.579987  390.799988  390.799988
# 252  2022-02-28  387.329987  397.750000  382.130005  397.467499  397.467499
#
#       Volume
# 0    3041400
# 1    3042200
# ...

# %%
comp9=pd.read_csv("Downloads/little_project/SONY.csv")
comp9
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-03-01  107.330002  108.559998  106.849998  108.080002  108.080002
# 1    2021-03-02  107.180000  107.260002  105.750000  105.769997  105.769997
# 2    2021-03-03  106.410004  106.570000  104.500000  104.519997  104.519997
# 3    2021-03-04  103.309998  104.019997  100.730003  101.839996  101.839996
# 4    2021-03-05  103.610001  104.250000  101.279999  104.139999  104.139999
# ..          ...         ...         ...         ...         ...         ...
# 248  2022-02-22  102.099998  104.339996  102.099998  102.680000  102.680000
# 249  2022-02-23  103.470001  103.870003  101.029999  101.309998  101.309998
# 250  2022-02-24   97.279999  102.110001   97.269997  101.989998  101.989998
# 251  2022-02-25  102.879997  104.330002  102.160004  104.089996  104.089996
# 252  2022-02-28  102.519997  103.099998  102.163300  102.879997  102.879997
#
#       Volume
# 0     935600
# 1    1082500
# ...

# %%
comp10=pd.read_csv("Downloads/little_project/TSLAnew.csv")
comp10
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-03-01  690.109985  719.000000  685.049988  718.429993  718.429993
# 1    2021-03-02  718.280029  721.109985  685.000000  686.440002  686.440002
# 2    2021-03-03  687.989990  700.700012  651.710022  653.200012  653.200012
# 3    2021-03-04  655.799988  668.450012  600.000000  621.440002  621.440002
# 4    2021-03-05  626.059998  627.840027  539.489990  597.950012  597.950012
# ..          ...         ...         ...         ...         ...         ...
# 248  2022-02-22  834.130005  856.729980  801.099976  821.530029  821.530029
# 249  2022-02-23  830.429993  835.299988  760.559998  764.039978  764.039978
# 250  2022-02-24  700.390015  802.479980  700.000000  800.770020  800.770020
# 251  2022-02-25  809.229980  819.500000  782.400024  809.869995  809.869995
# 252  2022-02-28  815.010010  873.750000  814.707520  871.849976  871.849976
#
#        Volume
# 0    27136200
# 1    23732200
# ...

# %% [markdown]
# ## After the data has been uploaded,we are now going to conduct our analysis using the average open and close prices

# %%
#importing the string library for indexing purposes
import string
Alph=string.ascii_uppercase
Alphlist=list(Alph)[0:10]
#compouting the different open avg price(arithmetic mean)
avg1=comp1['Open'].mean()
avg2=comp2['Open'].mean()
avg3=comp3['Open'].mean()
avg4=comp4['Open'].mean()
avg5=comp5['Open'].mean()
avg6=comp6['Open'].mean()
avg7=comp7['Open'].mean()
avg8=comp8['Open'].mean()
avg9=comp9['Open'].mean()
avg10=comp10['Open'].mean()
#computing the different close avg price(arithmetic mean)
avgc1=comp1['Close'].mean()
avgc2=comp2['Close'].mean()
avgc3=comp3['Close'].mean()
avgc4=comp4['Close'].mean()
avgc5=comp5['Close'].mean()
avgc6=comp6['Close'].mean()
avgc7=comp7['Close'].mean()
avgc8=comp8['Close'].mean()
avgc9=comp9['Close'].mean()
avgc10=comp10['Close'].mean()

# %% [markdown]
# ## we will be using the above with the goal of creating a more global dataframe

# %%
#creating a dictionary with the above variables
Datadic={'Stocks':['AAPL','AEP','AMZN','BABA','FB','GOOG','MSFT','NFLX','SONY','TSLA'],'Openavgs':[avg1,avg2,avg3,avg4,avg5,avg6,avg7,avg8,avg9,avg10],'Closeavgs':[avgc1,avgc2,avgc3,avgc4,avgc5,avgc6,avgc7,avgc8,avgc9,avgc10]}
#Creating the targeted dataframe using the dictionary 
Data=pd.DataFrame(Datadic)
Data.index=Alphlist
Data
# Out:
#   Stocks     Openavgs    Closeavgs
# A   AAPL   146.588696   146.745218
# B    AEP    85.970474    85.983733
# C   AMZN  3324.081863  3322.063838
# D   BABA   178.501146   178.191793
# E     FB   322.317253   322.433083
# F   GOOG  2630.108801  2629.821466
# G   MSFT   286.908221   286.988340
# H   NFLX   544.344426   543.912479
# I   SONY   108.784625   108.695889
# J   TSLA   801.282411   800.886678

# %%
#we are going to add anoother column called 'Decisive'
Decisive=[]
for i in range(len(Data['Openavgs'])):
    if Data['Openavgs'][i]<Data['Closeavgs'][i]:
        Decisive.append(1)
    else:
        Decisive.append(-1)
Data['Decisive']=Decisive
Data
# Out:
#   Stocks     Openavgs    Closeavgs  Decisive
# A   AAPL   146.588696   146.745218         1
# B    AEP    85.970474    85.983733         1
# C   AMZN  3324.081863  3322.063838        -1
# D   BABA   178.501146   178.191793        -1
# E     FB   322.317253   322.433083         1
# F   GOOG  2630.108801  2629.821466        -1
# G   MSFT   286.908221   286.988340         1
# H   NFLX   544.344426   543.912479        -1
# I   SONY   108.784625   108.695889        -1
# J   TSLA   801.282411   800.886678        -1

# %%
rep = plt.figure()
ax = rep.add_axes([0,0,1,1])
Stocks=['AAPL','AEP','AMZN','BABA','FB','GOOG','MSFT','NFLX','SONY','TSLA']
plt.plot(Stocks,Decisive)
plt.show()

# %% [markdown]
# ### The above +1 value corresponds to an average positive trend in our collection of stocks,while -1 represents the negative trend. We want to look in a simple way at the general trend on the market on a yearly basis( Data collected from ending February 2021 to ending February 2022).

# %%
#We will simply add the values in the "Decisive" column and conclude the analysis using the obtained result
Conclusion=0
for dec in Data['Decisive']:
    Conclusion+=dec

# %% [markdown]
# # printing the result

# %%
Conclusion
# Out:
# -2

# %% [markdown]
# #### For our sample of 10 stocks, the genral conculsion of the study reveals that the trend was generally negative. But as we took a sample of 10, we cannot precisely have the genral picture of the market on a yearly basis. The sample needs to be increased for more precision.These 10 stocks are all from companies composing the Nasdaq American index,with stock from tech companies ,not to be mistaken with DOW. At the end of the study we concluded using our sample of 10,that the month of february would be negatively oriented.Indeed a simple calculation can be made using the open price ofor the month of feb and the closing price for the same month;using them to compute the monthly price variation to confirm the sample study.

# %% [markdown]
# #### THe open price for february was USD14,966.6 and closed with USD 14,237.8.we obtain a -5.1187% price variation for the Nasdaq index;confirming the general conclusion of the sample study(Decreasing trend).
